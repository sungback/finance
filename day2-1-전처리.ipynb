# %%
# 타이타닉 호 승객 생존 예측 미니 프로젝트 : 1. 분석 & 시각화 -> (2. 전처리) -> ML

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.info()
# 1. sex(object) ==> 숫자
# 2. age 263개의 결측치를 채우자
# 3. fare 의 1개의 결측치를 삭제하기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# 1. sex(object) ==> 숫자

# %%
df['sex2'] = df['sex'].map( {'female':1, 'male':0} )
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# 2. age 263개의 결측치를 채우자

# %%
df['age'].mean()
# Out:
# np.float64(29.8811345124283)

# %%
df.loc[ df['age'].isnull(), 'age' ]
# Out:
# 15     NaN
# 37     NaN
# 40     NaN
# 46     NaN
# 59     NaN
#         ..
# 1293   NaN
# 1297   NaN
# 1302   NaN
# 1303   NaN
# 1305   NaN
# Name: age, Length: 263, dtype: float64

# %%
df.loc[ df['age'].isnull(), 'age' ] = 29.8

# %%
df.isnull().sum() # age   0 <== age 결측치 채움 성공
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# sex2            0
# dtype: int64

# %%
# 3. fare 의 결측치를 삭제하기

# %%
df = df.dropna(subset=['fare'])
df.shape # (1309 - 1 --> 1308, 15) ==> (1308, 15)
# Out:
# (1308, 15)

# %%
# 저장
df.to_csv('titanic_ok.csv', index=False) # index=False 는 인덱스는 빼고 저장

# %%
# 저장 후에는 꼭 다시 읽어서 이상이 없는지 점검할 것.
df2 = pd.read_csv('titanic_ok.csv')
df2
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1303       3         0                             Zabour, Miss. Hileni
# 1304       3         0                            Zabour, Miss. Thamine
# 1305       3         0                        Zakarian, Mr. Mapriededer
# 1306       3         0                              Zakarian, Mr. Ortin
# 1307       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# end
